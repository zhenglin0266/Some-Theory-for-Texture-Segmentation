# %% [markdown]
# ## GMRF model

# %%
import math
import matplotlib.pyplot as plt
import random
import numpy
import math
import matplotlib.pyplot as plt
import random
from k_means1 import k_means
from scipy import signal
from scipy.spatial.distance import pdist,squareform
from sklearn import cluster

# %%
from __future__ import print_function
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage,fcluster
import matplotlib
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
from sklearn.cluster import KMeans
from collections import Counter
import datetime

def accu(label, value):
    count1 = 0
    count2 = 0
    for h in range(len(label)):
        for g in range(len(label[0])):
            if h > (n-2*m)/2-1 and label[h][g] ==1:
                count1 += 1
            if h <(n-2*m)/2 and label[h][g] ==1:
                count2 += 1
    return max(abs(count1-value)+count2, abs(count2-value)+count1)/(value*2)

n = 128
m = round(n**0.5)
r = round(n**0.5)
mat1 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
mat2 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
for v in range(-r,r+1):
    mat1[r-v][r+v] = 1/(2*r+1)
    mat2[r][r-v] = 1/(2*r+1)

result_s = []
result_ps = []
result_k = []
for rr in range(50):
    print(rr)
    start_time = datetime.datetime.now() 
    nn= int((n+2*r)*(n+2*r))
    data1 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
    data2 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
    data = data1[:n,:n]
    data12 = data2[:n,:n]
    for g in range(n):
        for h in range(n):
            da1 = data1[g:g+2*r+1,h:h+2*r+1]
            da2 = data2[g:g+2*r+1,h:h+2*r+1]
            data[g][h] = sum(sum(np.multiply(mat1, da1)))
            data12[g][h] = sum(sum(np.multiply(mat2, da2)))

    data = data - numpy.mean(data)
    data = data/numpy.std(data)
    data12 = data12 - numpy.mean(data12)
    data12 = data12/numpy.std(data12)

    for h in range(n):
        for g in range(n):
            if h > n/2-1:
                data[h][g]=data12[h][g]
    plt.imshow(data, cmap='gray')
    plt.show()

    lis = []
    for i in range(m, n-m):
        for j in range(m, n-m):
            mat = data[i-m:i+m+1,j-m:j+m+1]
            matt = numpy.rot90(mat, 2)/((2*m+1)**2)
            res = signal.convolve2d(mat, matt, mode='full')
            res = res[m:3*m+1,m:3*m+1]
            res = res.flatten().tolist()
            res.append(3*i/n)
            res.append(3*j/n)
            lis.append(res)        
    

    Z = linkage(lis, 'single')
    ZZ = Z[:,3]
    y= 0
    while ZZ[y] <= ((n-2*m)**2)*0.6:
        y=y+1
    y=y-1
    label = fcluster(Z,Z[y,2],'distance')
    print(max(Z[0:y,3])/((n-2*m)**2))

    val = Counter(label).most_common(1)[0][0]
    label = [0 if x!=val else 1 for x in label]
    label1 = np.array(label).reshape(n-2*m,n-2*m)
    value = (n-2*m)**2/2
    accuracy0 = accu(label1,value)
    print(accuracy0, sum(sum(label1))/(value*2))

    plt.imshow(label1, cmap='gray')
    plt.show()


    clst=cluster.AgglomerativeClustering(n_clusters=2,linkage='ward')
    label11=clst.fit_predict(lis).reshape(n-2*m,n-2*m)
    value = (n-2*m)**2/2
    accuracy1 = accu(label11,value)
    print(accuracy1, sum(sum(label11))/(value*2))
    plt.imshow(label11, cmap='gray')
    plt.show()


    Clu1, label1 = k_means(lis, 2, 10)
    label11 = np.array(label1).reshape(n-2*m,n-2*m)
    value = (n-2*m)**2/2
    accuracy2 = accu(label11,value)
    print(accuracy2, sum(sum(label11))/(value*2))
    plt.imshow(label11, cmap='gray')
    plt.show()
    
    result_s.append(accuracy0)
    result_ps.append(accuracy1)
    result_k.append(accuracy2)
    end_time = datetime.datetime.now()     
    interval = (end_time-start_time).seconds
    final_time = interval/60.0 
    print ('Time:\t', final_time)
    
print('Single:',np.mean(result_s))
print('Ward:',np.mean(result_ps))
print('K-means:',np.mean(result_k))
# Out:
# 0
# 0.535243859024564
# 0.9099323602705589 0.5357778568885725
# 0.9696511213955145 0.5283908864364543
# 0.9856710573157708 0.5064969740121039
# Time:	 4.683333333333334
# 1
# 0.4765040939836241
# 0.976504093983624 0.4765040939836241
# 0.974190103239587 0.49875400498398004
# 0.9787290850836596 0.4929690281238875
# Time:	 4.466666666666667
# 2
# 0.4224813100747597
# 0.9224813100747598 0.4224813100747597
# 0.9369882520469918 0.4369882520469918
# 0.9598611605553578 0.5330188679245284
# Time:	 4.35
# 3
# 0.42986828052687787
# 0.9298682805268779 0.42986828052687787
# 0.9767710929156284 0.4831790672837309
# 0.9750800996796013 0.48789604841580636
# Time:	 3.316666666666667
# 4
# 0.4995550017799929
# 0.9995550017799929 0.4995550017799929
# 0.9677821288714845 0.4677821288714845
# 0.9891420434318263 0.5048059807760769
# Time:	 3.25
# 5
# 0.49056603773584906
# 0.9905660377358491 0.49056603773584906
# 0.9605731577073692 0.46715913136347453
# 0.9836240655037379 0.5078319686721253
# Time:	 3.216666666666667
# 6
# 0.593627625489498
# 0.9049483802064792 0.593627625489498
# 0.9732111071555714 0.49083303666785333
# 0.988252046991812 0.49341402634389464
# Time:	 3.283333333333333
# 7
# 0.5985226059095764
# 0.9014773940904236 0.5985226059095764
# 0.9493592025631897 0.542808828764685
# 0.9849590601637593 0.5082769668921324
# Time:	 5.183333333333334
# 8
# 0.5991456034175864
# 0.8802954788180847 0.5992346030615877
# 0.9694731221075116 0.4741011035955856
# 0.9756140975436098 0.5194019223923104
# Time:	 4.516666666666667
# 9
# 0.5754716981132075
# 0.9245283018867925 0.5754716981132075
# 0.9438412246351015 0.44384122463510145
# 0.9775720897116411 0.5106799572801709
# Time:	 4.466666666666667
# 10
# 0.5753826984692061
# 0.924439302242791 0.5753826984692061
# 0.9563011747953009 0.4817550729797081
# 0.9866500533997864 0.4983980064079744
# Time:	 4.516666666666667
# 11
# 0.599501601993592
# 0.8538625845496618 0.599501601993592
# 0.9624421502313991 0.5336418654325382
# 0.9828230687077252 0.5016909932360271
# Time:	 4.716666666666667
# 12
# 0.5968316126735493
# 0.8985404058383767 0.5968316126735493
# 0.9857600569597722 0.4900320398718405
# 0.9838910644357423 0.49083303666785333
# Time:	 4.733333333333333
# 13
# 0.5218049127803489
# 0.9625311498754004 0.5218049127803489
# 0.970185119259523 0.5271448914204343
# 0.9843360626557494 0.5156639373442506
# Time:	 4.333333333333333
# 14
# 0.502936988252047
# 0.9945710217159132 0.502936988252047
# 0.9887860448558206 0.49911000355998575
# 0.9788180847276611 0.5048059807760769
# 0.9691171235315059 0.5246529013883945
# 0.9816660733357067 0.5170879316482734
# Time:	 3.2666666666666666
# 34
# 0.5797436810252758
# 0.8889284442862229 0.5797436810252758
# 0.9627091491634033 0.4710751156995372
# 0.9831790672837308 0.5056069775720897
# Time:	 3.3
# 35
# 0.5997686009255963
# 0.872997508009968 0.5997686009255963
# 0.975881096475614 0.493503025987896
# 0.965379138483446 0.534620861516554
# Time:	 3.25
# 36
# 0.5863296546813813
# 0.9134923460306159 0.5863296546813813
# 0.9849590601637593 0.5020469918120327
# 0.9913670345318619 0.5048949804200783
# Time:	 3.1166666666666667
# 37
# 0.5773406906372375
# 0.9226593093627625 0.5773406906372375
# 0.974813100747597 0.48353506585973655
# 0.980064079743681 0.48006407974368104
# Time:	 3.2
# 38
# 0.5938946244215023
# 0.8988074047703809 0.5938946244215023
# 0.974190103239587 0.5250978996084016
# 0.9857600569597722 0.4983980064079744
# Time:	 3.1166666666666667
# 39
# 0.5269668921324314
# 0.9703631185475258 0.5269668921324314
# 0.9833570665717337 0.49581701673193307
# 0.9864720541117835 0.49021003915984335
# Time:	 3.183333333333333
# 40
# 0.503559985760057
# 0.996440014239943 0.503559985760057
# 0.9401922392310431 0.44019223923104306
# 0.9774830900676398 0.49902100391598436
# Time:	 3.183333333333333
# 41
# 0.5086329654681381
# 0.975881096475614 0.5086329654681381
# 0.9504271982912068 0.4504271982912068
# 0.9746351014595942 0.4762370950516198
# Time:	 3.216666666666667
# 42
# 0.4488252046991812
# 0.9488252046991812 0.4488252046991812
# 0.9383232467070132 0.43832324670701317
# 0.988252046991812 0.5072979708081168
# Time:	 3.1333333333333333
# 43
# 0.49056603773584906
# 0.9905660377358491 0.49056603773584906
# 0.9493592025631897 0.44935920256318973
# 0.9833570665717337 0.5157529369882521
# Time:	 3.183333333333333
# 44
# 0.5855286578853685
# 0.9144713421146315 0.5855286578853685
# 0.9720541117835528 0.4911000355998576
# 0.9857600569597722 0.5039159843360627
# Time:	 3.1333333333333333
# 45
# 0.5849056603773585
# 0.9150943396226415 0.5849056603773585
# 0.9680491278034888 0.5271448914204343
# 0.9821110715557138 0.49279102883588466
# Time:	 3.2333333333333334
# 46
# 0.5989676041295835
# 0.8727305090779637 0.5991456034175864
# 0.9813990744037023 0.5079209683161268
# 0.9763260946956213 0.5149519401922392
# Time:	 3.066666666666667
# 47
# 0.5839266642933428
# 0.9159843360626557 0.5840156639373443
# 0.9640441438234247 0.5131719473122107
# 0.9752580989676042 0.5202919188323246
# Time:	 3.216666666666667
# 48
# 0.522872908508366
# 0.977127091491634 0.522872908508366
# 0.9749021003915984 0.4848700605197579
# 0.9814880740477038 0.5185119259522962
# Time:	 3.0833333333333335
# 49
# 0.5849056603773585
# 0.9150943396226415 0.5849056603773585
# 0.9342292630829476 0.4342292630829477
# 0.9828230687077252 0.5077429690281239
# Time:	 3.066666666666667
# Single: 0.9209594161623353
# Ward: 0.9656585973656105
# K-means: 0.9821876112495549

# %%
print('Single:',np.mean(result_s))
print('Ward:',np.mean(result_ps))
print('K-means:',np.mean(result_k))
# Out:
# Single: 0.9209594161623353
# Ward: 0.9656585973656105
# K-means: 0.9821876112495549

# %%
import matplotlib.pyplot as plt
import numpy as np
n = 128
m = round(n**0.5)
r = round(n**0.5)
nn= int((n+2*r)*(n+2*r))

plt.rcParams['figure.figsize'] = (9, 6)
plt.subplot(2,3,1)
mat1 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
mat2 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
for v in range(-r,r+1):
    mat1[r-v][r-v] = 1/(2*r+1)
    mat2[r-v][r+v] = 1/(2*r+1)
data1 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data2 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data = data1[:n,:n]
data12 = data2[:n,:n]
for g in range(n):
    for h in range(n):
        da1 = data1[g:g+2*r+1,h:h+2*r+1]
        da2 = data2[g:g+2*r+1,h:h+2*r+1]
        data[g][h] = sum(sum(np.multiply(mat1, da1)))
        data12[g][h] = sum(sum(np.multiply(mat2, da2)))

data = data - numpy.mean(data)
data = data/numpy.std(data)
data12 = data12 - numpy.mean(data12)
data12 = data12/numpy.std(data12)

for h in range(n):
    for g in range(n):
        if h > n/2-1:
            data[h][g]=data12[h][g]
plt.imshow(data, cmap='gray')
plt.title('Model 1 vs Model 2', fontsize =15)
    
plt.subplot(2,3,2)
mat1 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
mat2 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
for v in range(-r,r+1):
    mat1[r-v][r-v] = 1/(2*r+1)
    mat2[r][r-v] = 1/(2*r+1)
data1 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data2 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data = data1[:n,:n]
data12 = data2[:n,:n]
for g in range(n):
    for h in range(n):
        da1 = data1[g:g+2*r+1,h:h+2*r+1]
        da2 = data2[g:g+2*r+1,h:h+2*r+1]
        data[g][h] = sum(sum(np.multiply(mat1, da1)))
        data12[g][h] = sum(sum(np.multiply(mat2, da2)))

data = data - numpy.mean(data)
data = data/numpy.std(data)
data12 = data12 - numpy.mean(data12)
data12 = data12/numpy.std(data12)

for h in range(n):
    for g in range(n):
        if h > n/2-1:
            data[h][g]=data12[h][g]
plt.imshow(data, cmap='gray')
plt.title('Model 1 vs Model 3', fontsize =15)
    
plt.subplot(2,3,3)
mat1 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
mat2 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
for v in range(-r,r+1):
    mat1[r-v][r-v] = 1/(2*r+1)
    mat2[r-v][r] = 1/(2*r+1)
data1 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data2 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data = data1[:n,:n]
data12 = data2[:n,:n]
for g in range(n):
    for h in range(n):
        da1 = data1[g:g+2*r+1,h:h+2*r+1]
        da2 = data2[g:g+2*r+1,h:h+2*r+1]
        data[g][h] = sum(sum(np.multiply(mat1, da1)))
        data12[g][h] = sum(sum(np.multiply(mat2, da2)))

data = data - numpy.mean(data)
data = data/numpy.std(data)
data12 = data12 - numpy.mean(data12)
data12 = data12/numpy.std(data12)

for h in range(n):
    for g in range(n):
        if h > n/2-1:
            data[h][g]=data12[h][g]
plt.imshow(data, cmap='gray')
plt.title('Model 1 vs Model 4', fontsize =15)
    
plt.subplot(2,3,4)
mat1 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
mat2 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
for v in range(-r,r+1):
    mat1[r-v][r+v] = 1/(2*r+1)
    mat2[r][r-v] = 1/(2*r+1)
data1 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data2 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data = data1[:n,:n]
data12 = data2[:n,:n]
for g in range(n):
    for h in range(n):
        da1 = data1[g:g+2*r+1,h:h+2*r+1]
        da2 = data2[g:g+2*r+1,h:h+2*r+1]
        data[g][h] = sum(sum(np.multiply(mat1, da1)))
        data12[g][h] = sum(sum(np.multiply(mat2, da2)))
data = data - numpy.mean(data)
data = data/numpy.std(data)
data12 = data12 - numpy.mean(data12)
data12 = data12/numpy.std(data12)
for h in range(n):
    for g in range(n):
        if h > n/2-1:
            data[h][g]=data12[h][g]
plt.imshow(data, cmap='gray')
plt.title('Model 2 vs Model 3', fontsize =15)

plt.subplot(2,3,5)
mat1 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
mat2 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
for v in range(-r,r+1):
    mat1[r-v][r+v] = 1/(2*r+1)
    mat2[r-v][r] = 1/(2*r+1)
data1 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data2 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data = data1[:n,:n]
data12 = data2[:n,:n]
for g in range(n):
    for h in range(n):
        da1 = data1[g:g+2*r+1,h:h+2*r+1]
        da2 = data2[g:g+2*r+1,h:h+2*r+1]
        data[g][h] = sum(sum(np.multiply(mat1, da1)))
        data12[g][h] = sum(sum(np.multiply(mat2, da2)))
data = data - numpy.mean(data)
data = data/numpy.std(data)
data12 = data12 - numpy.mean(data12)
data12 = data12/numpy.std(data12)
for h in range(n):
    for g in range(n):
        if h > n/2-1:
            data[h][g]=data12[h][g]
plt.imshow(data, cmap='gray')
plt.title('Model 2 vs Model 4', fontsize =15)

plt.subplot(2,3,6)
mat1 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
mat2 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
for v in range(2*r+1):
    mat1[r][v] = 1/(2*r+1)
    mat2[v][r] = 1/(2*r+1)
data1 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data2 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
data = data1[:n,:n]
data12 = data2[:n,:n]
for g in range(n):
    for h in range(n):
        da1 = data1[g:g+2*r+1,h:h+2*r+1]
        da2 = data2[g:g+2*r+1,h:h+2*r+1]
        data[g][h] = sum(sum(np.multiply(mat1, da1)))
        data12[g][h] = sum(sum(np.multiply(mat2, da2)))
data = data - numpy.mean(data)
data = data/numpy.std(data)
data12 = data12 - numpy.mean(data12)
data12 = data12/numpy.std(data12)
for h in range(n):
    for g in range(n):
        if h > n/2-1:
            data[h][g]=data12[h][g]
plt.imshow(data, cmap='gray')
plt.title('Model 3 vs Model 4', fontsize =15)

plt.tight_layout()
plt.show()

# %%
from PIL import Image
def ImageToMatrix(filename):
    im = Image.open(filename)
    width,height = im.size
    im = im.convert("L") 
    data = im.getdata()
    data = np.matrix(data,dtype='float')/255.0
    
    data = data - numpy.mean(data)
    data = data/numpy.std(data)
    
    new_data = np.reshape(data,(height,width))
    return new_data
def MatrixToImage(data):
    data = data*255
    new_im = Image.fromarray(data.astype(np.uint8))
    return new_im

nn=80
n=2*nn
m = round(n**0.5)
fig =['D21.gif','D55.gif','D77.gif']

plt.rcParams['figure.figsize'] = (9, 3)
plt.subplot(1,3,1)
filename1 = fig[0]
data1 = ImageToMatrix(filename1)
filename2 = fig[1]
data2 = ImageToMatrix(filename2)
data = np.vstack((data1,data2))
data = data[(640-nn):(640+nn),0:n]
new_im = MatrixToImage(data)
plt.imshow(data, cmap=plt.cm.gray, interpolation='nearest')
plt.title('D21 vs D55', fontsize =15)

plt.subplot(1,3,2)
filename1 = fig[0]
data1 = ImageToMatrix(filename1)
filename2 = fig[2]
data2 = ImageToMatrix(filename2)
data = np.vstack((data1,data2))
data = data[(640-nn):(640+nn),0:n]
new_im = MatrixToImage(data)
plt.imshow(data, cmap=plt.cm.gray, interpolation='nearest')
plt.title('D21 vs D77', fontsize =15)

plt.subplot(1,3,3)
filename1 = fig[1]
data1 = ImageToMatrix(filename1)
filename2 = fig[2]
data2 = ImageToMatrix(filename2)
data = np.vstack((data1,data2))
data = data[(640-nn):(640+nn),0:n]
new_im = MatrixToImage(data)
plt.imshow(data, cmap=plt.cm.gray, interpolation='nearest')
plt.title('D55 vs D77', fontsize =15)
plt.tight_layout()
plt.show()

# %%
from PIL import Image
def ImageToMatrix(filename):
    im = Image.open(filename)
    width,height = im.size
    im = im.convert("L") 
    data = im.getdata()
    data = np.matrix(data,dtype='float')/255.0
    
    data = data - numpy.mean(data)
    data = data/numpy.std(data)
    
    new_data = np.reshape(data,(height,width))
    return new_data
def MatrixToImage(data):
    data = data*255
    new_im = Image.fromarray(data.astype(np.uint8))
    return new_im

nn=80
n=2*nn
m = round(n**0.5)
fig =['D21.gif','D55.gif','D77.gif']

plt.rcParams['figure.figsize'] = (9, 3)
plt.subplot(1,3,1)
filename1 = fig[0]
data1 = ImageToMatrix(filename1)
data = data1[0:n,0:n]
filename2 = fig[1]
data2 = ImageToMatrix(filename2)
data2 = data2[0:n,0:n]
co = 0
for kk in range(n):
    for jj in range(n):
        if ((kk-(nn-0.5))**2+(jj-(nn-0.5))**2 > 2859):
            co=co+1
            data[kk,jj] = data2[kk,jj]
#         print(co/(n**2))
new_im = MatrixToImage(data)
plt.imshow(data, cmap=plt.cm.gray, interpolation='nearest')
plt.title('D21 vs D55', fontsize =15)

plt.subplot(1,3,2)
filename1 = fig[0]
data1 = ImageToMatrix(filename1)
data = data1[0:n,0:n]
filename2 = fig[2]
data2 = ImageToMatrix(filename2)
data2 = data2[0:n,0:n]
co = 0
for kk in range(n):
    for jj in range(n):
        if ((kk-(nn-0.5))**2+(jj-(nn-0.5))**2 > 2859):
            co=co+1
            data[kk,jj] = data2[kk,jj]
#         print(co/(n**2))
new_im = MatrixToImage(data)
plt.imshow(data, cmap=plt.cm.gray, interpolation='nearest')
plt.title('D21 vs D77', fontsize =15)

plt.subplot(1,3,3)
filename1 = fig[1]
data1 = ImageToMatrix(filename1)
data = data1[0:n,0:n]
filename2 = fig[2]
data2 = ImageToMatrix(filename2)
data2 = data2[0:n,0:n]
co = 0
for kk in range(n):
    for jj in range(n):
        if ((kk-(nn-0.5))**2+(jj-(nn-0.5))**2 > 2859):
            co=co+1
            data[kk,jj] = data2[kk,jj]
#         print(co/(n**2))
new_im = MatrixToImage(data)
plt.imshow(data, cmap=plt.cm.gray, interpolation='nearest')
plt.title('D55 vs D77', fontsize =15)
plt.tight_layout()
plt.show()

# %%
from PIL import Image
def ImageToMatrix(filename):
    im = Image.open(filename)
    width,height = im.size
    im = im.convert("L") 
    data = im.getdata()
    data = np.matrix(data,dtype='float')/255.0
    
    data = data - numpy.mean(data)
    data = data/numpy.std(data)
    
    new_data = np.reshape(data,(height,width))
    return new_data
def MatrixToImage(data):
    data = data*255
    new_im = Image.fromarray(data.astype(np.uint8))
    return new_im

nn=80
n=2*nn
m = round(n**0.5)

plt.rcParams['figure.figsize'] = (9, 3)
plt.subplot(1,3,1)
fig =['D4.gif','D6.gif','D20.gif','D52.gif']
filename1 = fig[0]
data1 = ImageToMatrix(filename1)
data1 = data1[0:n,0:n]
filename2 = fig[1]
data2 = ImageToMatrix(filename2)
data2 = data2[0:n,0:n]
filename3 = fig[2]
data3 = ImageToMatrix(filename3)
data3 = data3[0:n,0:n]
filename4 = fig[3]
data4 = ImageToMatrix(filename4)
data = data4[0:n,0:n]
co = 0
c1 = 0
c2 = 0
for kk in range(n):
    for jj in range(n):
        if kk < nn and jj < nn:
            co=co+1
            data[kk,jj] = data1[kk,jj]
        elif kk >= nn and jj < nn:
            c1=c1+1
            data[kk,jj] = data2[kk,jj]
        elif kk < nn and jj >= nn:
            c2=c2+1
            data[kk,jj] = data3[kk,jj]
# print(co/(n**2),c1/(n**2),c2/(n**2))
new_im = MatrixToImage(data)
plt.imshow(data, cmap=plt.cm.gray, interpolation='nearest')
plt.title('D4, D6, D20 & D52', fontsize =15)

plt.subplot(1,3,2)
fig =['D21.gif','D34.gif','D55.gif','D77.gif']
filename1 = fig[0]
data1 = ImageToMatrix(filename1)
data1 = data1[0:n,0:n]
filename2 = fig[1]
data2 = ImageToMatrix(filename2)
data2 = data2[0:n,0:n]
filename3 = fig[2]
data3 = ImageToMatrix(filename3)
data3 = data3[0:n,0:n]
filename4 = fig[3]
data4 = ImageToMatrix(filename4)
data = data4[0:n,0:n]
co = 0
c1 = 0
c2 = 0
for kk in range(n):
    for jj in range(n):
        if kk < nn and jj < nn:
            co=co+1
            data[kk,jj] = data1[kk,jj]
        elif kk >= nn and jj < nn:
            c1=c1+1
            data[kk,jj] = data2[kk,jj]
        elif kk < nn and jj >= nn:
            c2=c2+1
            data[kk,jj] = data3[kk,jj]
# print(co/(n**2),c1/(n**2),c2/(n**2))
new_im = MatrixToImage(data)
plt.imshow(data, cmap=plt.cm.gray, interpolation='nearest')
plt.title('D21, D34, D55 & D77', fontsize =15)

plt.subplot(1,3,3)
fig =['D6.gif','D21.gif','D34.gif','D77.gif']
filename1 = fig[0]
data1 = ImageToMatrix(filename1)
data1 = data1[0:n,0:n]
filename2 = fig[1]
data2 = ImageToMatrix(filename2)
data2 = data2[0:n,0:n]
filename3 = fig[2]
data3 = ImageToMatrix(filename3)
data3 = data3[0:n,0:n]
filename4 = fig[3]
data4 = ImageToMatrix(filename4)
data = data4[0:n,0:n]
co = 0
c1 = 0
c2 = 0
for kk in range(n):
    for jj in range(n):
        if kk < nn and jj < nn:
            co=co+1
            data[kk,jj] = data1[kk,jj]
        elif kk >= nn and jj < nn:
            c1=c1+1
            data[kk,jj] = data2[kk,jj]
        elif kk < nn and jj >= nn:
            c2=c2+1
            data[kk,jj] = data3[kk,jj]
# print(co/(n**2),c1/(n**2),c2/(n**2))
new_im = MatrixToImage(data)
plt.imshow(data, cmap=plt.cm.gray, interpolation='nearest')
plt.title('D6, D21, D34 & D77', fontsize =15)
plt.tight_layout()
plt.show()

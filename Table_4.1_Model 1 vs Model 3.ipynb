# %% [markdown]
# ## GMRF model

# %%
import math
import matplotlib.pyplot as plt
import random
import numpy
import math
import matplotlib.pyplot as plt
import random
from k_means1 import k_means
from scipy import signal
from scipy.spatial.distance import pdist,squareform
from sklearn import cluster

# %%
from __future__ import print_function
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage,fcluster
import matplotlib
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
from sklearn.cluster import KMeans
from collections import Counter
import datetime

def accu(label, value):
    count1 = 0
    count2 = 0
    for h in range(len(label)):
        for g in range(len(label[0])):
            if h > (n-2*m)/2-1 and label[h][g] ==1:
                count1 += 1
            if h <(n-2*m)/2 and label[h][g] ==1:
                count2 += 1
    return max(abs(count1-value)+count2, abs(count2-value)+count1)/(value*2)

n = 128
m = round(n**0.5)
r = round(n**0.5)
mat1 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
mat2 =  np.array([float(0) for i in range((2*r+1)**2)]).reshape(2*r+1, 2*r+1)
for v in range(-r,r+1):
    mat1[r-v][r-v] = 1/(2*r+1)
    mat2[r][r-v] = 1/(2*r+1)

result_s = []
result_ps = []
result_k = []
for rr in range(50):
    print(rr)
    start_time = datetime.datetime.now() 
    nn= int((n+2*r)*(n+2*r))
    data1 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
    data2 = np.random.normal(0, 1, nn).reshape(int(n+2*r), int(n+2*r))
    data = data1[:n,:n]
    data12 = data2[:n,:n]
    for g in range(n):
        for h in range(n):
            da1 = data1[g:g+2*r+1,h:h+2*r+1]
            da2 = data2[g:g+2*r+1,h:h+2*r+1]
            data[g][h] = sum(sum(np.multiply(mat1, da1)))
            data12[g][h] = sum(sum(np.multiply(mat2, da2)))

    data = data - numpy.mean(data)
    data = data/numpy.std(data)
    data12 = data12 - numpy.mean(data12)
    data12 = data12/numpy.std(data12)

    for h in range(n):
        for g in range(n):
            if h > n/2-1:
                data[h][g]=data12[h][g]
    plt.imshow(data, cmap='gray')
    plt.show()

    lis = []
    for i in range(m, n-m):
        for j in range(m, n-m):
            mat = data[i-m:i+m+1,j-m:j+m+1]
            matt = numpy.rot90(mat, 2)/((2*m+1)**2)
            res = signal.convolve2d(mat, matt, mode='full')
            res = res[m:3*m+1,m:3*m+1]
            res = res.flatten().tolist()
            res.append(3*i/n)
            res.append(3*j/n)
            lis.append(res)        
    

    Z = linkage(lis, 'single')
    ZZ = Z[:,3]
    y= 0
    while ZZ[y] <= ((n-2*m)**2)*0.6:
        y=y+1
    y=y-1
    label = fcluster(Z,Z[y,2],'distance')
    print(max(Z[0:y,3])/((n-2*m)**2))

    val = Counter(label).most_common(1)[0][0]
    label = [0 if x!=val else 1 for x in label]
    label1 = np.array(label).reshape(n-2*m,n-2*m)
    value = (n-2*m)**2/2
    accuracy0 = accu(label1,value)
    print(accuracy0, sum(sum(label1))/(value*2))

    plt.imshow(label1, cmap='gray')
    plt.show()


    clst=cluster.AgglomerativeClustering(n_clusters=2,linkage='ward')
    label11=clst.fit_predict(lis).reshape(n-2*m,n-2*m)
    value = (n-2*m)**2/2
    accuracy1 = accu(label11,value)
    print(accuracy1, sum(sum(label11))/(value*2))
    plt.imshow(label11, cmap='gray')
    plt.show()


    Clu1, label1 = k_means(lis, 2, 10)
    label11 = np.array(label1).reshape(n-2*m,n-2*m)
    value = (n-2*m)**2/2
    accuracy2 = accu(label11,value)
    print(accuracy2, sum(sum(label11))/(value*2))
    plt.imshow(label11, cmap='gray')
    plt.show()
    
    result_s.append(accuracy0)
    result_ps.append(accuracy1)
    result_k.append(accuracy2)
    end_time = datetime.datetime.now()     
    interval = (end_time-start_time).seconds
    final_time = interval/60.0 
    print ('Time:\t', final_time)
    
print('Single:',np.mean(result_s))
print('Ward:',np.mean(result_ps))
print('K-means:',np.mean(result_k))
# Out:
# 0
# 0.5970986116055536
# 0.8962264150943396 0.598433606265575
# 0.9566571733713065 0.47196511213955145
# 0.9739231043075828 0.48656105375578496
# Time:	 7.683333333333334
# 1
# 0.5998576005695977
# 0.88875044499822 0.5998576005695977
# 0.9320932716269135 0.43209327162691347
# 0.9790850836596654 0.4951050195799217
# Time:	 7.85
# 2
# 0.4898540405838377
# 0.9887860448558206 0.4898540405838377
# 0.9556781772872909 0.4556781772872909
# 0.990121039515842 0.4967070131719473
# Time:	 7.583333333333333
# 3
# 0.5705767176931292
# 0.9260412958348166 0.5705767176931292
# 0.9626201495194019 0.5373798504805981
# 0.9797970808116767 0.519312922748309
# Time:	 7.716666666666667
# 4
# 0.5724457102171592
# 0.9272872908508366 0.5725347098611605
# 0.9592381630473478 0.46208615165539335
# 0.9694731221075116 0.4694731221075116
# Time:	 7.633333333333334
# 5
# 0.5187789248843004
# 0.9810430758276967 0.5187789248843004
# 0.9720541117835528 0.47899608401566396
# 0.9864720541117835 0.5040939836240655
# Time:	 7.766666666666667
# 6
# 0.5987006051975792
# 0.8899074403702385 0.5987006051975792
# 0.9765930936276255 0.5153969384122463
# 0.9878070487718049 0.49830900676397294
# Time:	 8.016666666666667
# 7
# 0.5951406194375223
# 0.882431470274119 0.5951406194375223
# 0.9609291562833748 0.46466714133143466
# 0.9848700605197579 0.4848700605197579
# Time:	 8.35
# 8
# 0.5973656105375579
# 0.8709505161979352 0.5973656105375579
# 0.974190103239587 0.518689925240299
# 0.9902990388038447 0.5043609825560698
# Time:	 8.083333333333334
# 9
# 0.5888216447134211
# 0.9111783552865789 0.5888216447134211
# 0.9860270558917764 0.5043609825560698
# 0.9838020647917408 0.5096119615521538
# Time:	 8.05
# 10
# 0.5845496618013528
# 0.9154503381986472 0.5845496618013528
# 0.9756140975436098 0.511747953008188
# 0.9871840512637949 0.5065859736561054
# Time:	 8.183333333333334
# 11
# 0.5992346030615877
# 0.8716625133499466 0.5993236027055892
# 0.9556781772872909 0.4893200427198291
# 0.9810430758276967 0.49101103595585616
# Time:	 8.233333333333333
# 12
# 0.5882876468494126
# 0.906372374510502 0.5893556425774297
# 0.9407262370950517 0.4407262370950516
# 0.9812210751156996 0.48246707013171947
# Time:	 8.2
# 13
# 0.5188679245283019
# 0.9811320754716981 0.5188679245283019
# 0.9698291206835172 0.47481310074759703
# 0.9824670701317195 0.5077429690281239
# Time:	 8.083333333333334
# 14
# 0.5996796012815949
# 0.8985404058383767 0.5996796012815949
# 0.9838910644357423 0.4874510501957992
# 0.9822890708437166 0.5148629405482378
# Time:	 8.166666666666666
# 0.9792630829476682 0.47926308294766823
# 0.977750088999644 0.48006407974368104
# 0.9880740477038091 0.49750800996796013
# Time:	 5.1
# 34
# 0.46226415094339623
# 0.9622641509433962 0.46226415094339623
# 0.9684941260234959 0.4684941260234959
# 0.9844250622997508 0.4977750088999644
# Time:	 5.133333333333334
# 35
# 0.4862050551797793
# 0.9862050551797793 0.4862050551797793
# 0.9507831968672126 0.4536311854752581
# 0.9761480954076184 0.5238519045923816
# Time:	 5.35
# 36
# 0.5185119259522962
# 0.9814880740477038 0.5185119259522962
# 0.9612851548593806 0.4703631185475258
# 0.9654681381274475 0.4788180847276611
# Time:	 5.35
# 37
# 0.5979886080455679
# 0.9020113919544321 0.5979886080455679
# 0.9703631185475258 0.5264328942684229
# 0.985315058739765 0.4922570309718761
# Time:	 5.433333333333334
# 38
# 0.5471698113207547
# 0.9528301886792453 0.5471698113207547
# 0.9707191171235315 0.5161089355642577
# 0.9854930580277679 0.48816304734781063
# Time:	 5.35
# 39
# 0.5770736917052331
# 0.9229263082947669 0.5770736917052331
# 0.9867390530437878 0.49421502313990745
# 0.9757920968316127 0.4788180847276611
# Time:	 5.466666666666667
# 40
# 0.5471698113207547
# 0.9528301886792453 0.5471698113207547
# 0.9399252402990388 0.44081523673905304
# 0.9829120683517266 0.4841580633677465
# Time:	 5.316666666666666
# 41
# 0.5509967960128159
# 0.8977394090423638 0.5910466358134567
# 0.9539871840512638 0.5460128159487362
# 0.974813100747597 0.48211107155571375
# Time:	 5.133333333333334
# 42
# 0.5994126023495906
# 0.835439658241367 0.5994126023495906
# 0.9234603061587754 0.4234603061587754
# 0.9788180847276611 0.5126379494482022
# Time:	 5.116666666666666
# 43
# 0.5996796012815949
# 0.8988964044143823 0.5996796012815949
# 0.9611071555713777 0.5388928444286223
# 0.9763260946956213 0.4807760768956924
# Time:	 5.066666666666666
# 44
# 0.5870416518333926
# 0.8558205767176932 0.5882876468494126
# 0.9509611961552153 0.4509611961552154
# 0.990121039515842 0.5011569953720185
# Time:	 5.1
# 45
# 0.4870950516197935
# 0.9870950516197935 0.4870950516197935
# 0.9574581701673194 0.4587041651833393
# 0.9617301530793877 0.4617301530793877
# Time:	 5.316666666666666
# 46
# 0.5323068707725169
# 0.9247953008187967 0.5323068707725169
# 0.9864720541117835 0.4989320042719829
# 0.977750088999644 0.5220719117123531
# Time:	 5.7
# 47
# 0.5262548949804201
# 0.9320932716269135 0.5262548949804201
# 0.9515841936632253 0.5338198647205411
# 0.9844250622997508 0.50062299750801
# Time:	 5.633333333333334
# 48
# 0.5914916340334638
# 0.8988964044143823 0.5914916340334638
# 0.9633321466714133 0.4729441082235671
# 0.9779280882876469 0.5179779280882877
# Time:	 5.5
# 49
# 0.4158063367746529
# 0.915806336774653 0.4158063367746529
# 0.9712531149875401 0.493503025987896
# 0.9891420434318263 0.5026699893200427
# Time:	 5.566666666666666
# Single: 0.9144054823780705
# Ward: 0.9632128871484514
# K-means: 0.9820256318974724

# %%
print('Single:',np.mean(result_s))
print('Ward:',np.mean(result_ps))
print('K-means:',np.mean(result_k))
# Out:
# Single: 0.9144054823780705
# Ward: 0.9632128871484514
# K-means: 0.9820256318974724
